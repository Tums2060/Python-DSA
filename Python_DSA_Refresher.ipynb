# %% [markdown]
# 1. Write a program that asks the user for a number of days. The program then
# prints out the number of seconds in the amount of days given

# %%
days = int(input("What are the number of days?"))

# To get total seconds I multiply the number of days to 24 which will give me hours then to 60 to give me minutes then 60 again to give me seconds
total_seconds = days*24*60*60
print(total_seconds)
# Out:
# 172800

# %% [markdown]
# 2. Write a program that asks a user to input the radius then the program
# calculates the volume of a sphere (the formula for the volume is (4/3)πr3
# ). Use the exponential operator in python to compute (r3)

# %%
radius = int(input("What is the radius of your sphere?"))

# Implementing the formula for calculating volume of a sphere with the exponential operator
volume_sphere = (4/3*22/7)*radius**3
print(f"The volume of your sphere, whose radius is {radius} is {volume_sphere}")
# Out:
# The volume of your sphere, whose radius is 20 is 33523.80952380953

# %% [markdown]
# 3. Using functions, write a program to compute the area and perimeter of a
# square. The program should ask the user to enter a number corresponding to
# the side length of the square and display the area and perimeter of the
# square.

# %%
def area_perimeter():
    side_length = int(input("What is the length of your square in cm? "))

    # area is length squared
    area = side_length * side_length
    
    # perimeter is length x 4
    perimeter = side_length * 4
    return print(f"Your square of length {side_length}, has an area of {area} cm sqrd and a perimeter of {perimeter} cm")

def main():
    output = area_perimeter()

if __name__ == "__main__":
    main()
# Out:
# Your square of length 4, has an area of 16 cm sqrd and a perimeter of 16 cm

# %% [markdown]
# 4. Write a program using functions that determines whether a character input
# by a user is uppercase or lower case.

# %%
def upper_lowecase():
    user_character = input("What is your character? ")
    #I used the inbuilt python function "isupper"
    output = user_character.isupper()

    # The function outputs True if the character is actually uppercase, so here, if output also means if true
    if output:
        print("Your character is Upper case")
    else:
        print("Your character is Lower case")

def main():
    result = upper_lowecase()

if __name__ == "__main__":
    main()
# Out:
# Your character is Lower case

# %% [markdown]
# 5. The following is pseudocode for a program being designed. Write the
# Python program equivalent of the same.

# %%
def loop_function():
    x = 0
    y = 20

    # I used a while statement to loop through the addition and subtraction
    while True:
        y = y - 4
        x = x + (2/y)

        # This is the condition to stop the while loop
        if y < 6:
            break

    print(x)

def main():
    output = loop_function()

if __name__ == "__main__":
    main()
# Out:
# 1.0416666666666665

# %% [markdown]
# 6. Write a Python program that does the following:
# • Uses a loop for a user to continually input 5 values to populate an
# array.
# • Calculates and displays the average of the values input into the array.

# %%
import statistics

def mean_list():
    # Initialized an empty list which will be appended with inputed values
    final_list = []

    while True:
        list_items = int(input("Enter the numbers for your list: "))

        # Here I append first before performing the check, because if the check comes fist, it will results in an extra loop before termination
        final_list.append(list_items)

        # Since a list starts from 0, 0-4 gives 5 values
        if len(final_list) > 4:
            break

    # Use the statistics library to get the mean of the list
    mean_oflist = statistics.mean(final_list)

    print(f"The mean of values in your list {final_list} is {mean_oflist}")

def main():
    result = mean_list()

if __name__ == "__main__":
    main()
# Out:
# The mean of values in your list [1, 2, 3, 4, 5] is 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
